# %%
import pandas as pd

# %%
df = pd.read_csv('/home/raj/jupyter pandas/survey_results_public.csv',index_col='Respondent')

# %%
df
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
# ...                                                       ...      ...   ...
# 64858                                                     NaN      Yes   NaN
# 64867                                                     NaN      Yes   NaN
# 64898                                                     NaN      Yes   NaN
# 64925                                                     NaN      Yes   NaN
# 65112                                                     NaN      Yes   NaN
#
# ...

# %%
df.shape
# Out:
# (64461, 60)

# %%
pd.set_option('display.max_columns',61)
pd.set_option('display.max_row',61)

# %%
schema_df = pd.read_csv('/home/raj/jupyter pandas/survey_results_schema.csv',index_col='Column')

# %%
schema_df
# Out:
#                                                                    QuestionText
# Column
# Respondent                    Randomized respondent ID number (not in order ...
# MainBranch                    Which of the following options best describes ...
# Hobbyist                                                Do you code as a hobby?
# Age                           What is your age (in years)? If you prefer not...
# Age1stCode                    At what age did you write your first line of c...
# CompFreq                       Is that compensation weekly, monthly, or yearly?
# CompTotal                     What is your current total compensation (salar...
# ConvertedComp                 Salary converted to annual USD salaries using ...
# Country                                                      Where do you live?
# CurrencyDesc                  Which currency do you use day-to-day? If your ...
# CurrencySymbol                Which currency do you use day-to-day? If your ...
# ...

# %%
schema_df.loc['Hobbyist','QuestionText']
# Out:
# 'Do you code as a hobby?'

# %%
df.rename(columns={'ConvertedComp':'SalaryUSD'},inplace = True)

# %%
high_salary = df['SalaryUSD'] > 70000
df[high_salary]
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 8                              I am a developer by profession      Yes  36.0
# 16                             I am a developer by profession      Yes  45.0
# 17                             I am a developer by profession      Yes  25.0
# 18                             I am a developer by profession      Yes  32.0
# 19                             I am a developer by profession       No  24.0
# ...                                                       ...      ...   ...
# 65586                          I am a developer by profession      Yes   NaN
# 65589                          I am a developer by profession      Yes   NaN
# 65602       I am not primarily a developer, but I write co...      Yes   NaN
# 65604                          I am a developer by profession       No   NaN
# 65617                          I am a developer by profession      Yes   NaN
#
# ...

# %%
countries = ['United States	','United Kingdom','India','Germany']

# %%
df.loc[high_salary,['Country','WebframeWorkedWith','SalaryUSD']]
# Out:
#                    Country                     WebframeWorkedWith  SalaryUSD
# Respondent
# 8            United States                                  Flask   116000.0
# 16          United Kingdom                        jQuery;React.js   108576.0
# 17           United States  ASP.NET;Gatsby;jQuery;React.js;Vue.js    79000.0
# 18           United States                                    NaN  1260000.0
# 19           United States        Angular;Angular.js;ASP.NET Core    83400.0
# ...                    ...                                    ...        ...
# 65586        United States                                    NaN   225000.0
# 65589        United States                                    NaN   150000.0
# 65602        United States                                    NaN   140000.0
# 65604        United States                                    NaN   150000.0
# 65617              Germany                                    NaN   129718.0
#
# [13178 rows x 3 columns]

# %%
python_salary = (df['WebframeWorkedWith'] == 'Django') & (df['SalaryUSD'])
df.loc[python_salary,['WebframeWorkedWith','SalaryUSD']]
# Out:
#            WebframeWorkedWith  SalaryUSD
# Respondent
# 83                     Django     3036.0
# 262                    Django   171000.0
# 654                    Django    16250.0
# 766                    Django    11820.0
# 808                    Django    66000.0
# ...                       ...        ...
# 62271                  Django    12000.0
# 62365                  Django    12372.0
# 62378                  Django    75454.0
# 62570                  Django    60000.0
# 62866                  Django   200000.0
#
# [428 rows x 2 columns]

# %%
filt = (df['WebframeWorkedWith'].str.contains('Django',na=False)) & (df['SalaryUSD'])
df.loc[filt,['WebframeWorkedWith','SalaryUSD']]
# Out:
#                                            WebframeWorkedWith  SalaryUSD
# Respondent
# 11                         Angular;Angular.js;Django;React.js    40070.0
# 26                                            Django;React.js    71093.0
# 33                 Angular;Angular.js;Django;Express;React.js    63564.0
# 51                                            Django;React.js   103615.0
# 69                                               Django;Flask   594539.0
# ...                                                       ...        ...
# 64938                       Django;Flask;jQuery;Ruby on Rails    59454.0
# 65341       Angular;ASP.NET;Django;Express;Flask;React.js;...  2000000.0
# 65458                         Angular;Django;Express;React.js    19104.0
# 65527                    Django;Express;Flask;React.js;Spring  2000000.0
# 65596         Angular.js;Django;jQuery;React.js;Ruby on Rails    70000.0
#
# [3245 rows x 2 columns]

# %%
df.rename(columns={'ConvertedComp':'SalaryUSD'},inplace=True)

# %%
df
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
# ...                                                       ...      ...   ...
# 64858                                                     NaN      Yes   NaN
# 64867                                                     NaN      Yes   NaN
# 64898                                                     NaN      Yes   NaN
# 64925                                                     NaN      Yes   NaN
# 65112                                                     NaN      Yes   NaN
#
# ...

# %%
df.sort_values(by=['Country','SalaryUSD'],ascending=[True,False],inplace=True)

# %%
df[['Country','SalaryUSD']].head(50)
# Out:
#                 Country  SalaryUSD
# Respondent
# 62788       Afghanistan  1000000.0
# 65381       Afghanistan  1000000.0
# 65456       Afghanistan  1000000.0
# 38672       Afghanistan   231192.0
# 28374       Afghanistan   130000.0
# 9839        Afghanistan    23328.0
# 63848       Afghanistan    23328.0
# 51862       Afghanistan    20950.0
# 51509       Afghanistan    20220.0
# 44484       Afghanistan    18660.0
# 15422       Afghanistan    18000.0
# 2932        Afghanistan    16335.0
# 26540       Afghanistan    13992.0
# 57269       Afghanistan    10884.0
# 26775       Afghanistan     8016.0
# 30568       Afghanistan     5448.0
# 30522       Afghanistan     4668.0
# 28811       Afghanistan     4509.0
# 34969       Afghanistan     4356.0
# 26857       Afghanistan     2328.0
# 33878       Afghanistan     1860.0
# 35753       Afghanistan      780.0
# 18049       Afghanistan      109.0
# 35295       Afghanistan        0.0
# 898         Afghanistan        NaN
# ...

# %%
df['SalaryUSD'].nlargest(10)
# Out:
# Respondent
# 5725     2000000.0
# 54263    2000000.0
# 43430    2000000.0
# 59279    2000000.0
# 46711    2000000.0
# 123      2000000.0
# 125      2000000.0
# 193      2000000.0
# 665      2000000.0
# 699      2000000.0
# Name: SalaryUSD, dtype: float64

# %%
df.nlargest(10,'SalaryUSD')
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 5725                           I am a developer by profession       No  26.0
# 54263                          I am a developer by profession      Yes  29.0
# 43430                          I am a developer by profession      Yes  33.0
# 59279                          I am a developer by profession      Yes   NaN
# 46711                          I am a developer by profession      Yes   NaN
# 123                            I am a developer by profession      Yes  26.0
# 125         I am not primarily a developer, but I write co...      Yes  41.0
# 193                            I am a developer by profession      Yes  29.0
# 665                            I am a developer by profession      Yes  24.0
# 699         I am not primarily a developer, but I write co...      Yes  39.0
#
#                       Age1stCode CompFreq     CompTotal  SalaryUSD  \
# Respondent
# ...

# %%
# if we want to to fetch smallest then use nsmallest

df.nsmallest(10,'SalaryUSD')
# Out:
#                                 MainBranch Hobbyist   Age Age1stCode CompFreq  \
# Respondent
# 35295       I am a developer by profession      Yes   NaN         13  Monthly
# 47357       I am a developer by profession      Yes   NaN          5   Weekly
# 6054        I am a developer by profession      Yes  38.0         15   Yearly
# 27135       I am a developer by profession       No   NaN         16   Yearly
# 60292       I am a developer by profession      Yes   NaN         12   Yearly
# 38813       I am a developer by profession       No   NaN         18  Monthly
# 8470        I am a developer by profession      Yes   NaN          5  Monthly
# 41006       I am a developer by profession      Yes  22.0         17   Yearly
# 15493       I am a developer by profession       No  44.0         17  Monthly
# 57369       I am a developer by profession       No  44.0         18  Monthly
#
#             CompTotal  SalaryUSD      Country        CurrencyDesc  \
# Respondent
# ...

# %%
df['SalaryUSD'].median()
# Out:
# 54049.0

# %%
df.median()
# Out:
# Age               29.0
# CompTotal      63000.0
# SalaryUSD      54049.0
# WorkWeekHrs       40.0
# dtype: float64

# %%
df.describe()
# Out:
#                 Age      CompTotal     SalaryUSD   WorkWeekHrs
# count  45446.000000   3.482600e+04  3.475600e+04  41151.000000
# mean      30.834111  3.190464e+242  1.037561e+05     40.782174
# std        9.585392            inf  2.268853e+05     17.816383
# min        1.000000   0.000000e+00  0.000000e+00      1.000000
# 25%       24.000000   2.000000e+04  2.464800e+04     40.000000
# 50%       29.000000   6.300000e+04  5.404900e+04     40.000000
# 75%       35.000000   1.250000e+05  9.500000e+04     44.000000
# max      279.000000  1.111111e+247  2.000000e+06    475.000000

# %%
df['Hobbyist'].value_counts()
# Out:
# Yes    50388
# No     14028
# Name: Hobbyist, dtype: int64

# %%
df['Country'].value_counts()
# Out:
# United States       12469
# India                8403
# United Kingdom       3896
# Germany              3890
# Canada               2191
#                     ...
# Nauru                   1
# Fiji                    1
# Liechtenstein           1
# Kiribati                1
# Marshall Islands        1
# Name: Country, Length: 183, dtype: int64

# %%
# now instead of groupby we can also see the data
# but this is not a right way to filter group by works best 
# coz it groups by all the countries and a single ones
flit = df['Country'] == 'India'
df.loc[flit]['LanguageWorkedWith']
# Out:
# Respondent
# 37655    C#;Dart;Java;Objective-C;Python;SQL;Swift
# 36976                                          NaN
# 3332                      Go;Java;Python;Scala;SQL
# 8457       Assembly;C;C++;HTML/CSS;Java;Python;SQL
# 21351                        Bash/Shell/PowerShell
#                            ...
# 54757    C;HTML/CSS;Java;JavaScript;PHP;Python;SQL
# 55407                                          NaN
# 62464                                          NaN
# 62954                                          SQL
# 64236                                          NaN
# Name: LanguageWorkedWith, Length: 8403, dtype: object

# %%
country_grp = df.groupby(['Country'])

# %%
country_grp.get_group('India')
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 37655                          I am a developer by profession       No   NaN
# 36976       I am not primarily a developer, but I write co...       No   NaN
# 3332                           I am a developer by profession      Yes   NaN
# 8457                           I am a developer by profession      Yes  22.0
# 21351                          I am a developer by profession       No  98.0
# ...                                                       ...      ...   ...
# 54757                                                     NaN      Yes   NaN
# 55407                                                     NaN      Yes   NaN
# 62464                                                     NaN      Yes   NaN
# 62954                                                     NaN      Yes   NaN
# 64236                                                     NaN      Yes   NaN
#
# ...

# %%
# value_counts(normalize=True) to get the percent values
country_grp['LanguageWorkedWith'].value_counts(normalize=True).loc['India']
# Out:
# LanguageWorkedWith
# HTML/CSS;JavaScript;PHP;SQL       0.026148
# HTML/CSS;JavaScript               0.021644
# Java                              0.021644
# HTML/CSS;JavaScript;TypeScript    0.017577
# Python                            0.014962
#                                     ...
# Python;Rust                       0.000145
# Python;TypeScript                 0.000145
# R                                 0.000145
# R;Ruby                            0.000145
# SQL;Swift                         0.000145
# Name: LanguageWorkedWith, Length: 2280, dtype: float64

# %%
country_grp['SalaryUSD'].median().loc['India']
# Out:
# 10056.0

# %%
country_grp['SalaryUSD'].agg(['median','mean']).loc['Canada']
# Out:
# median     68068.000000
# mean      115101.775465
# Name: Canada, dtype: float64

# %%
# flit = df['Country'] == 'India'
# df.loc[flit]['LanguageWorkedWith'].str.contains('Python').sum()

# %%
country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum()).loc['India']
# Out:
# 2670

# %%
country_respondents = df['Country'].value_counts()
country_respondents
# Out:
# United States       12469
# India                8403
# United Kingdom       3896
# Germany              3890
# Canada               2191
#                     ...
# Nauru                   1
# Fiji                    1
# Liechtenstein           1
# Kiribati                1
# Marshall Islands        1
# Name: Country, Length: 183, dtype: int64

# %%
 country_uses_python = country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())

# %%
country_uses_python
# Out:
# Country
# Afghanistan                              11
# Albania                                  13
# Algeria                                  40
# Andorra                                   3
# Angola                                    1
#                                        ...
# Venezuela, Bolivarian Republic of...     29
# Viet Nam                                102
# Yemen                                     1
# Zambia                                    4
# Zimbabwe                                 13
# Name: LanguageWorkedWith, Length: 183, dtype: int64

# %%
python_df = pd.concat([country_respondents,country_uses_python],axis=1,sort=False)
python_df
# Out:
#                   Country  LanguageWorkedWith
# United States       12469                5964
# India                8403                2670
# United Kingdom       3896                1621
# Germany              3890                1712
# Canada               2191                1011
# ...                   ...                 ...
# Nauru                   1                   0
# Fiji                    1                   0
# Liechtenstein           1                   0
# Kiribati                1                   0
# Marshall Islands        1                   0
#
# [183 rows x 2 columns]

# %%
python_df.rename(columns={'Country':'NumRespondents','LanguageWorkedWith':'NumKnowPython'},inplace=True)

# %%
python_df
# Out:
#                   NumRespondents  NumKnowPython
# United States              12469           5964
# India                       8403           2670
# United Kingdom              3896           1621
# Germany                     3890           1712
# Canada                      2191           1011
# ...                          ...            ...
# Nauru                          1              0
# Fiji                           1              0
# Liechtenstein                  1              0
# Kiribati                       1              0
# Marshall Islands               1              0
#
# [183 rows x 2 columns]

# %%
python_df['PctKnowsPythn'] = (python_df['NumKnowPython']/python_df['NumRespondents'])

# %%
python_df
# Out:
#                   NumRespondents  NumKnowPython  PctKnowsPythn
# United States              12469           5964       0.478306
# India                       8403           2670       0.317744
# United Kingdom              3896           1621       0.416068
# Germany                     3890           1712       0.440103
# Canada                      2191           1011       0.461433
# ...                          ...            ...            ...
# Nauru                          1              0       0.000000
# Fiji                           1              0       0.000000
# Liechtenstein                  1              0       0.000000
# Kiribati                       1              0       0.000000
# Marshall Islands               1              0       0.000000
#
# [183 rows x 3 columns]

# %%
python_df.sort_values(by='PctKnowsPythn',ascending=False,inplace=True)

# %%
python_df.loc['India']
# Out:
# NumRespondents    8403.000000
# NumKnowPython     2670.000000
# PctKnowsPythn        0.317744
# Name: India, dtype: float64

# %%
df['YearsCode'].head(10)
# Out:
# Respondent
# 62788                   NaN
# 65381                    30
# 65456    More than 50 years
# 38672                    40
# 28374                    17
# 9839                     10
# 63848                    14
# 51862                     5
# 51509                     8
# 44484                     8
# Name: YearsCode, dtype: object

# %%
df['YearsCode'].unique()
# Out:
# array([nan, '30', 51, '40', '17', '10', '14', '5', '8', '9', '4', '6',
#        '3', '2', '35', '1', 0, '7', '12', '50', '19', '20', '11', '15',
#        '24', '27', '28', '16', '22', '13', '18', '25', '38', '34', '23',
#        '32', '21', '42', '33', '26', '29', '39', '48', '36', '47', '41',
#        '37', '31', '43', '44', '45', '46', '49'], dtype=object)

# %%
df['YearsCode'].replace('Less than 1 year',0,inplace=True)

# %%
df['YearsCode'].replace('More than 50 years',51,inplace=True)

# %%
df['YearsCode']
